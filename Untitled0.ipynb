# %% [markdown]
# <a href="https://colab.research.google.com/github/esteemeran/fefu-scripts/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
from skimage import io
import matplotlib.pyplot as plt
from PIL import Image
print("OpenCV-Python Version {}".format(cv2.__version__))

#convertation
x = 2592
y = 1944
imgSize = (x,y)

rawData = open("/content/drive/MyDrive/Colab Notebooks/macbeth_2592x1944_bpp14_RG.raw", 'rb').read()
# Use the PIL raw decoder to read the data.
img = Image.frombuffer("P", imgSize, rawData, "raw")
img.save("foo.png")

# loading the image from the disk
#image = io.imread('foo.png') #gray+
image = cv2.imread('foo.png', cv2.IMREAD_COLOR) #gray+

image = cv2.cvtColor(image, cv2.COLOR_HLS2RGB) #lgray+
image = cv2.cvtColor(image, cv2.COLOR_HLS2RGB) #lgray+
#image = cv2.cvtColor(image, cv2.COLOR_HLS2RGB) #lgray+



#image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) #gray+
#image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) #gray+
#image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) #gray+

image = cv2.cvtColor(image, cv2.COLOR_Luv2RGB) #red+
#image = cv2.cvtColor(image, cv2.COLOR_Luv2RGB) #red+

image = cv2.cvtColor(image, cv2.COLOR_XYZ2RGB) #brown+
#image = cv2.cvtColor(image, cv2.COLOR_XYZ2RGB) #brown+

image = cv2.cvtColor(image, cv2.COLOR_YUV2RGB) #green greydot

image = cv2.cvtColor(image, cv2.COLOR_Lab2RGB) #blue reddot

image = cv2.cvtColor(image, cv2.COLOR_YCrCb2RGB) #green
#image = cv2.cvtColor(image, cv2.COLOR_YCrCb2RGB) #green

image = cv2.cvtColor(image, cv2.COLOR_HSV2RGB) #brown green+
#image = cv2.cvtColor(image, cv2.COLOR_HSV2RGB) #brown green+
#image = cv2.cvtColor(image, cv2.COLOR_HSV2RGB) #brown+
#image = cv2.cvtColor(image, cv2.COLOR_HSV2RGB) #brown+



#image = cv2.cvtColor(image, cv2.COLOR_RGBA2RGB) #gray+


#image = cv2.cvtColor(image, cv2.COLOR_HLS2RGB) #lgray+
#image = cv2.cvtColor(image, cv2.COLOR_HLS2RGB) #lgray+
#image = cv2.cvtColor(image, cv2.COLOR_HLS2RGB) #lgray+
#image = cv2.cvtColor(image, cv2.COLOR_HLS2RGB) #lgray+
#image = cv2.cvtColor(image, cv2.COLOR_HLS2RGB) #lgray+






plt.imshow(image)
plt.show()
# Out:
# OpenCV-Python Version 4.8.0
